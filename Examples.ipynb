# %%
import os
from pprint import pprint

import pandas as pd
from meadiator.core.meadiator import Meadiator, Run, Experiment, Analysis, Meadia

# %%
release_dir = r"J:\hte_jcap_app_proto\share\pub\pub-20190606084911-all"
cache_dir = r"D:\Sync\jcap\mead"
os.chdir(cache_dir)

# %% [markdown]
# `release_dir` source location of public release

# %% [markdown]
# `cache_dir` save location for mediator object cache

# %% [markdown]
# ### Initialize mediator class and load objects

# %%
m = Meadiator(release_dir)
m.load_objects(overwrite_cache=True)
# Out:
# found existing file dictionary in D:\Sync\jcap\mead\pub-20190606084911-all_files.bz2.pck
# found 943 plate files in J:\hte_jcap_app_proto\share\pub\pub-20190606084911-all\plate
# found 9662 run files in J:\hte_jcap_app_proto\share\pub\pub-20190606084911-all\run
# found 3322 exp files in J:\hte_jcap_app_proto\share\pub\pub-20190606084911-all\experiment
# found 3275 ana files in J:\hte_jcap_app_proto\share\pub\pub-20190606084911-all\analysis
# 09:51:17 loading plate objects
# 09:51:24 loading run objects
# 09:54:20 loading exp objects
# 09:55:17 loading ana objects
# Could not read metafile in J:\hte_jcap_app_proto\share\pub\pub-20190606084911-all\analysis\eche\20170331.105112.copied-20170331221423327PDT.zip
# Could not read metafile in J:\hte_jcap_app_proto\share\pub\pub-20190606084911-all\analysis\eche\20170421.174903.copied-20170421221456483PDT.zip
# Could not read metafile in J:\hte_jcap_app_proto\share\pub\pub-20190606084911-all\analysis\eche\20170421.175019.copied-20170421221456483PDT.zip
# Could not read metafile in J:\hte_jcap_app_proto\share\pub\pub-20190606084911-all\analysis\eche\20170427.113234.copied-20170427221603653PDT.zip
# Could not read metafile in J:\hte_jcap_app_proto\share\pub\pub-20190606084911-all\analysis\eche\20170502.180600.copied-20170503221428485PDT.zip
# Could not read metafile in J:\hte_jcap_app_proto\share\pub\pub-20190606084911-all\analysis\eche\20170503.143618.copied-20170504221436407PDT.zip
# 09:56:49 1730 files were not loaded due to read errors, see meadia['load_errors']
# 09:56:56 46 runs/exps/anas are present in plate info files but were not included in the release, see meadia['load_errors']
# 09:57:00 wrote object dictionary to D:\Sync\jcap\mead\pub-20190606084911-all_objects.bz2.pck

# %% [markdown]
# ***

# %% [markdown]
# ## Example 1: Bi-V system

# %% [markdown]
# _Note: the terms "plate" and "library" are used interchangeably_

# %% [markdown]
# __1a.__ find all libraries containing Bi and V

# %%
PLATE_FILTER: dict = {"has_element": ["Bi", "V"]}

library_list = m.find_plates(PLATE_FILTER)
len(library_list)
# Out:
# 78

# %% [markdown]
# `.find_plates()` method returns a list of plate objects

# %% [markdown]
# __1b.__ find all libraries containing Bi and V, which have electrochemistry and x-ray fluorescence measurements (raw data)

# %%
PLATE_FILTER: dict = {"has_element": ["Bi", "V"], "has_run_type": ["eche", "xrfs"]}

library_with_run = m.find_plates(PLATE_FILTER)
len(library_with_run)
# Out:
# 11

# %% [markdown]
# __1c.__ Bi-V libraries with electrochemistry and x-ray fluorescence analyses

# %%
PLATE_FILTER: dict = {"has_element": ["Bi", "V"], "has_ana_type": ["eche", "xrfs"]}

library_with_analysis = m.find_plates(PLATE_FILTER)
len(library_with_analysis)
# Out:
# 10

# %% [markdown]
# ***

# %% [markdown]
# __2.__ Accessing plate [library] attributes

# %%
p = library_with_analysis[0]

# %%
type(p)
# Out:
# meadiator.core.meadiator.Plate

# %% [markdown]
# __2a.__ All plate objects contain basic attributes such as source zip, plate_id number, intended composition space, substrate, and synthesis conditions. The plate library below contains mixtures of Cu, Bi, and V -oxides, synthesized on Pyrex glass with FTO back contact, and oxygen-annealed at 550 deg. C.

# %% [markdown]
# ```
# >pprint(vars(p), depth=2, compact=True)
#
# {'ana_dict': {'eche': {...}, 'ssrl': {...}, 'uvis': {...}, 'xrfs': {...}},
#  'analyses': ['/xrfs/20170707.174048.copied-20170711173346196PDT.zip',
#               '/eche/20170802.120309.copied-20170802223436842PDT.zip',
#               '/uvis/20170719.223457.copied-20170808222257815PDT.zip',
#               '/ssrl/20170823.140526.copied-20170823234456363PDT.zip',
#               '/xrfs/20170907.125058.copied-20170907221545763PDT.zip',
#               '/ssrl/20171011.113239.copied-20171016151616488PDT.zip',
#               '/eche/20171026.171237.copied-20171026221656817PDT.zip',
#               '/eche/20171026.110954.copied-20171026221656817PDT.zip',
#               '/eche/20171101.155431.copied-20171101220806730PDT.zip',
#               '/ssrl/20171011.113240.copied-20171129084916724PST.zip',
#               '/eche/20180409.161243.copied-20180409221847769PDT.zip',
#               '/eche/20180716.143317.copied-20180716220818351PDT.zip'],
#  'anneal_date': '2017-01-18',
#  'anneal_temp': 550.0,
#  'anneal_type': 'O',
#  'date': '2015-04-21 16:24:27 PDT',
#  'deposition_method': 'PVD',
#  'elements': ['V', 'O', 'Cu', 'Bi', 'Ar'],
#  'exp_dict': {'eche': {...}, 'ssrl': {...}, 'uvis': {...}, 'xrfs': {...}},
#  'experiments': ['/xrfs/20170707.174048.copied-20170711173113950PDT.zip',
#                  '/uvis/20170719.223437.copied-20170720220800660PDT.zip',
#                  '/eche/20170802.120418.copied-20170802221206976PDT.zip',
#                  '/ssrl/20170823.140526.copied-20170823233029640PDT.zip',
#                  '/ssrl/20170823.121127.copied-20170823233029640PDT.zip',
#                  '/ssrl/20170922.123540.copied-20171014165743612PDT.zip',
#                  '/eche/20171026.171234.copied-20171026220643581PDT.zip',
#                  '/eche/20171026.110548.copied-20171026220643581PDT.zip',
#                  '/eche/20171101.155614.copied-20171101220429135PDT.zip'],
#  'lineage': 2783,
#  'map': 57,
#  'path': 'J:\\hte_jcap_app_proto\\share\\pub\\pub-20190606084911-all\\plate\\2783\\2783.zip',
#  'plate_id': 2783,
#  'run_dict': {'eche': {...}, 'ssrl': {...}, 'uvis': {...}, 'xrfs': {...}},
#  'runs': ['/xrfs/hte-xrfs-01/20170707_Cu-Bi-V_27830/20170707.174048.copied-20170711164145651PDT.zip',
#           '/uvis/hte-uvis-02/20170719_CuBiVArO_T-UVVIS_27830/20170719.144141.copied-20170719220229259PDT.zip',
#           '/uvis/hte-uvis-02/20170719_CuBiVArO_R-UVVIS_27830/20170719.141521.copied-20170719220229259PDT.zip',
#           '/uvis/hte-uvis-02/20170719_CuBiVArO_T-UVVIS_27830/20170719.141521.copied-20170719220229259PDT.zip',
#           '/eche/hte-eche-04/20170724_BiCuVO_27830/20170724.110308.copied-20170724165739847PDT.zip',
#           '/eche/hte-eche-04/20170724_BiCuVO_27830/20170724.115545.copied-20170724165830344PDT.zip',
#           '/eche/hte-eche-04/20170724_BiCuVO_27830/20170724.114638.copied-20170724165855361PDT.zip',
#           '/eche/hte-eche-04/20170724_BiCuVO_27830/20170724.104841.copied-20170724165949355PDT.zip',
#           '/eche/hte-eche-04/20170724_BiCuVO_27830/20170724.110644.copied-20170724170012788PDT.zip',
#           '/ssrl/hte-ssrl-01/20170823_CuBiVArO_27830/20170520.182813.copied-20170823220407387PDT.zip',
#           '/ssrl/hte-ssrl-01/20170921_CuBiVArO_27830/20170520.182813.copied-20170921220453629PDT.zip',
#           '/ssrl/hte-ssrl-01/20170922_CuBiVArO_27830/20170520.182813.copied-20170922220333723PDT.zip',
#           '/eche/hte-eche-04/20171025_CuBiVO_27830/20171025.175031.copied-20171025220316783PDT.zip',
#           '/eche/hte-eche-04/20171025_CuBiVO_27830/20171025.174737.copied-20171025220316783PDT.zip',
#           '/eche/hte-eche-04/20171025_CuBiVO_27830/20171025.174305.copied-20171025220316783PDT.zip',
#           '/eche/hte-eche-04/20171025_CuBiVO_27830/20171025.173330.copied-20171025220316783PDT.zip',
#           '/eche/hte-eche-04/20171025_CuBiVO_27830/20171025.172931.copied-20171025220316783PDT.zip',
#           '/eche/hte-eche-04/20171026_CuBiVO_27830/20171026.164255.copied-20171026170556161PDT.zip',
#           '/eche/hte-eche-04/20171026_CuBiVO_27830/20171026.162030.copied-20171026170705241PDT.zip',
#           '/eche/hte-eche-04/20171026_CuBiVO_27830/20171026.163049.copied-20171026170842357PDT.zip',
#           '/eche/hte-eche-04/20171026_CuBiVO_27830/20171026.161825.copied-20171026170922524PDT.zip',
#           '/eche/hte-eche-04/20171101_CuBiVO_27830/20171101.113557.copied-20171101153846172PDT.zip',
#           '/eche/hte-eche-04/20171101_CuBiVO_27830/20171101.114259.copied-20171101154108659PDT.zip',
#           '/eche/hte-eche-04/20171101_CuBiVO_27830/20171101.113125.copied-20171101154347343PDT.zip',
#           '/eche/hte-eche-04/20171101_CuBiVO_27830/20171101.141133.copied-20171101154419221PDT.zip',
#           '/eche/hte-eche-04/20171101_CuBiVO_27830/20171101.121350.copied-20171101220308635PDT.zip'],
#  'substrate': 'Round Tec15 pyrex FTO'}
# ```

# %% [markdown]
# __2b.__ Transform plate object list into a pandas dataframe

# %%
platedf = pd.DataFrame([vars(x) for x in library_with_analysis])
platedf
# Out:
#                                                 path  plate_id  \
# 0  J:\hte_jcap_app_proto\share\pub\pub-2019060608...      2783
# 1  J:\hte_jcap_app_proto\share\pub\pub-2019060608...      3202
# 2  J:\hte_jcap_app_proto\share\pub\pub-2019060608...      3459
# 3  J:\hte_jcap_app_proto\share\pub\pub-2019060608...      3581
# 4  J:\hte_jcap_app_proto\share\pub\pub-2019060608...      3591
# 5  J:\hte_jcap_app_proto\share\pub\pub-2019060608...      3592
# 6  J:\hte_jcap_app_proto\share\pub\pub-2019060608...      3593
# 7  J:\hte_jcap_app_proto\share\pub\pub-2019060608...      3804
# 8  J:\hte_jcap_app_proto\share\pub\pub-2019060608...      3924
# 9  J:\hte_jcap_app_proto\share\pub\pub-2019060608...      3925
#
#                       date  lineage                         elements  \
# 0  2015-04-21 16:24:27 PDT     2783               [Bi, Ar, O, Cu, V]
# 1  2015-09-02 13:47:48 PDT     3202                   [V, Ar, O, Bi]
# 2  2016-01-25 17:05:32 PST     3459                   [V, Ar, O, Bi]
# 3  2016-03-30 15:35:12 PDT     3581                [, Bi, Ar, V, Fe]
# 4  2016-03-30 15:53:56 PDT     3591               [Bi, O, Ar, V, Fe]
# 5  2016-03-30 15:53:56 PDT     3592                [, Bi, Ar, V, Fe]
# 6  2016-03-30 15:53:56 PDT     3593               [Bi, O, Ar, V, Fe]
# 7  2016-09-02 10:53:15 PDT     3804  [Gd, Ca, Mo, Ce, Bi, V, Fe, Cr]
# 8  2016-12-08 11:58:45 PST     3924               [Mn, Bi, O, Ar, V]
# 9  2016-12-08 11:58:45 PST     3925               [Cu, O, Ar, Bi, V]
#
#   deposition_method              substrate  map  anneal_temp anneal_type  \
# 0               PVD  Round Tec15 pyrex FTO   57        550.0           O
# 1               PVD   Round Tec7 glass FTO   57        550.0           O
# 2               PVD   Round Tec7 glass FTO   57        610.0           O
# 3               PVD  Round Tec15 pyrex FTO   57        500.0           O
# 4               PVD  Round Tec15 pyrex FTO   57        550.0           O
# 5               PVD  Round Tec15 pyrex FTO   57        500.0           O
# 6               PVD  Round Tec15 pyrex FTO   57        550.0           O
# 7            INKJET       Glass FTO Tec 15   72        565.0           O
# 8               PVD  Round Tec15 pyrex FTO   57        610.0           O
# 9               PVD  Round Tec15 pyrex FTO   57        610.0           O
#
#   anneal_date                                           run_dict  \
# 0  2017-01-18  {'eche': {'20170724.104841.copied-201707241659...
# 1  2016-02-17  {'eche': {'20160226.135948.copied-201602261620...
# 2  2016-03-07  {'eche': {'20160310.170402.copied-201603101843...
# 3  2016-11-01  {'eche': {'20170803.110836.copied-201708032204...
# 4  2016-11-15  {'eche': {'20170804.112830.copied-201708041752...
# 5  2016-11-10  {'eche': {'20170714.105930.copied-201707142203...
# 6  2016-11-15  {'eche': {'20170809.112637.copied-201708092203...
# 7  2016-09-08  {'eche': {'20161206.164623.copied-201612062203...
# 8  2017-10-03  {'eche': {'20171109.105047.copied-201711101108...
# 9  2017-10-03  {'eche': {'20171020.110934.copied-201710201720...
#
#                                             exp_dict  \
# 0  {'eche': {'20170802.120418.copied-201708022212...
# 1  {'eche': {'20160229.105032.copied-201602292202...
# 2  {'eche': {'20160310.184511.copied-201603102209...
# 3  {'eche': {'20170804.122427.copied-201708042207...
# 4  {'eche': {'20170807.141447.copied-201708151826...
# 5  {'eche': {'20170802.125607.copied-201708022212...
# 6  {'eche': {'20170810.140609.copied-201708102208...
# 7  {'eche': {'20161209.102640.copied-201612092210...
# 8  {'eche': {'20171110.112545.copied-201711101142...
# 9  {'eche': {'20171020.172955.copied-201710202211...
#
#                                             ana_dict  \
# 0  {'eche': {'20170802.120309.copied-201708022234...
# 1  {'eche': {'20160229.104731.copied-201602292205...
# 2  {'eche': {'20160310.183451.copied-201604291336...
# 3  {'eche': {'20170804.122403.copied-201708151848...
# 4  {'eche': {'20170807.141440.copied-201708151848...
# 5  {'eche': {'20170802.125552.copied-201708022234...
# 6  {'eche': {'20170810.140454.copied-201708102214...
# 7  {'eche': {'20161219.151113.copied-201612192258...
# 8  {'eche': {'20171110.112505.copied-201711101219...
# 9  {'eche': {'20171020.172904.copied-201710202217...
#
#                                                 runs  \
# 0  [/xrfs/hte-xrfs-01/20170707_Cu-Bi-V_27830/2017...
# 1  [/eche/hte-eche-05/20160412_BiVO_32027/2016041...
# 2  [/eche/hte-eche-05/20160414_BiVO_34591/2016041...
# 3  [/uvis/hte-uvis-02/20161118_VFeBiAr_T-UVVIS_35...
# 4  [/xrfs/hte-xrfs-01/20161129_V-Fe-Bi-O_35918/20...
# 5  [/uvis/hte-uvis-02/20161118_VFeBiAr_T-UVVIS_35...
# 6  [/uvis/hte-uvis-02/20161118_VFeBiArO_T-UVVIS_3...
# 7  [/metr/hte-metr-01/20161118_BiVVFeCaCrGdMoCe_3...
# 8  [/xrfs/hte-xrfs-01/20171005_MnBiVO_39248/20171...
# 9  [/xrfs/hte-xrfs-01/20171004_CuBiVO_39259/20171...
#
#                                          experiments  \
# 0  [/xrfs/20170707.174048.copied-2017071117311395...
# 1  [/eche/20160412.170408.copied-2016041222062131...
# 2  [/eche/20160414.152128.copied-2016041422070436...
# 3  [/xrfs/20161107.171535.copied-2016111722102550...
# 4  [/xrfs/20161129.175247.copied-2016120122561501...
# 5  [/uvis/20161204.120248.copied-2016120422094105...
# 6  [/uvis/20161204.171916.copied-2016120422094105...
# 7  [/imag/20161121.100208.copied-2016112110465439...
# 8  [/xrfs/20171005.092555.copied-2017100612401503...
# 9  [/xrfs/20171004.151328.copied-2017100612401503...
#
#                                             analyses
# 0  [/xrfs/20170707.174048.copied-2017071117334619...
# 1  [/eche/20160412.170020.copied-2016042122033344...
# 2  [/eche/20160414.151501.copied-2016042122033344...
# 3  [/xrfs/20161107.171535.copied-2016111722233546...
# 4  [/xrfs/20161129.175247.copied-2016120422255804...
# 5  [/uvis/20161204.120219.copied-2016122022365980...
# 6  [/uvis/20161204.171847.copied-2016122208421116...
# 7  [/xrfs/20161117.122053.copied-2016121522472104...
# 8  [/xrfs/20171005.092555.copied-2017100612522153...
# 9  [/xrfs/20171004.151328.copied-2017100612522153...

# %% [markdown]
# All plate objects also link directly to run, experiment, and analysis objects through the `run_dict`, `exp_dict`, and `ana_dict` attributes. The object dictionaries are keyed by type (e.g. "xrds", "xrfs", "uvis") then by source filename.

# %% [markdown]
# __2c.__ Transform run list into dataframe

# %%
rundf = pd.DataFrame([vars(x) for _, x in p.run_dict["eche"].items()])
rundf
# Out:
#                                                  path  \
# 0   J:\hte_jcap_app_proto\share\pub\pub-2019060608...
# 1   J:\hte_jcap_app_proto\share\pub\pub-2019060608...
# 2   J:\hte_jcap_app_proto\share\pub\pub-2019060608...
# 3   J:\hte_jcap_app_proto\share\pub\pub-2019060608...
# 4   J:\hte_jcap_app_proto\share\pub\pub-2019060608...
# 5   J:\hte_jcap_app_proto\share\pub\pub-2019060608...
# 6   J:\hte_jcap_app_proto\share\pub\pub-2019060608...
# 7   J:\hte_jcap_app_proto\share\pub\pub-2019060608...
# 8   J:\hte_jcap_app_proto\share\pub\pub-2019060608...
# 9   J:\hte_jcap_app_proto\share\pub\pub-2019060608...
# 10  J:\hte_jcap_app_proto\share\pub\pub-2019060608...
# 11  J:\hte_jcap_app_proto\share\pub\pub-2019060608...
# 12  J:\hte_jcap_app_proto\share\pub\pub-2019060608...
# 13  J:\hte_jcap_app_proto\share\pub\pub-2019060608...
# 14  J:\hte_jcap_app_proto\share\pub\pub-2019060608...
# 15  J:\hte_jcap_app_proto\share\pub\pub-2019060608...
# 16  J:\hte_jcap_app_proto\share\pub\pub-2019060608...
# 17  J:\hte_jcap_app_proto\share\pub\pub-2019060608...
# 18  J:\hte_jcap_app_proto\share\pub\pub-2019060608...
#
#                        date  type  plate_id      machine            elements  \
# 0   2017-07-24 10:48:41 PDT  eche      2783  hte-eche-04  [Bi, Ar, O, Cu, V]
# 1   2017-07-24 11:03:08 PDT  eche      2783  hte-eche-04  [Bi, Ar, O, Cu, V]
# 2   2017-07-24 11:06:44 PDT  eche      2783  hte-eche-04  [Bi, Ar, O, Cu, V]
# 3   2017-07-24 11:46:38 PDT  eche      2783  hte-eche-04  [Bi, Ar, O, Cu, V]
# 4   2017-07-24 11:55:45 PDT  eche      2783  hte-eche-04  [Bi, Ar, O, Cu, V]
# 5   2017-10-25 17:29:31 PDT  eche      2783  hte-eche-04  [Bi, Ar, O, Cu, V]
# 6   2017-10-25 17:33:30 PDT  eche      2783  hte-eche-04  [Bi, Ar, O, Cu, V]
# 7   2017-10-25 17:43:05 PDT  eche      2783  hte-eche-04  [Bi, Ar, O, Cu, V]
# 8   2017-10-25 17:47:37 PDT  eche      2783  hte-eche-04  [Bi, Ar, O, Cu, V]
# 9   2017-10-25 17:50:31 PDT  eche      2783  hte-eche-04  [Bi, Ar, O, Cu, V]
# 10  2017-10-26 16:18:25 PDT  eche      2783  hte-eche-04  [Bi, Ar, O, Cu, V]
# 11  2017-10-26 16:20:30 PDT  eche      2783  hte-eche-04  [Bi, Ar, O, Cu, V]
# 12  2017-10-26 16:30:49 PDT  eche      2783  hte-eche-04  [Bi, Ar, O, Cu, V]
# 13  2017-10-26 16:42:55 PDT  eche      2783  hte-eche-04  [Bi, Ar, O, Cu, V]
# 14  2017-11-01 11:31:25 PDT  eche      2783  hte-eche-04  [Bi, Ar, O, Cu, V]
# 15  2017-11-01 11:35:57 PDT  eche      2783  hte-eche-04  [Bi, Ar, O, Cu, V]
# 16  2017-11-01 11:42:59 PDT  eche      2783  hte-eche-04  [Bi, Ar, O, Cu, V]
# 17  2017-11-01 12:13:50 PDT  eche      2783  hte-eche-04  [Bi, Ar, O, Cu, V]
# 18  2017-11-01 14:11:33 PDT  eche      2783  hte-eche-04  [Bi, Ar, O, Cu, V]
#
#     anneal_temp anneal_type file_count  \
# 0         550.0           O         30
# 1         550.0           O         12
# 2         550.0           O        138
# 3         550.0           O         30
# 4         550.0           O       1002
# 5         550.0           O          3
# 6         550.0           O          6
# 7         550.0           O          4
# 8         550.0           O          2
# 9         550.0           O         10
# 10        550.0           O          2
# 11        550.0           O          8
# 12        550.0           O          8
# 13        550.0           O          6
# 14        550.0           O          4
# 15        550.0           O          2
# 16        550.0           O          3
# 17        550.0           O          2
# 18        550.0           O          2
#
#                                                 files  \
# 0   {'CA4': {'pstat_files': {'Sample27984_x42_y91_...
# 1   {'CA4': {'pstat_files': {'Sample28016_x58_y91_...
# 2   {'CA4': {'pstat_files': {'Sample26224_x38_y83_...
# 3   {'CA4': {'pstat_files': {'Sample23924_x54_y75_...
# 4   {'CA4': {'pstat_files': {'Sample120_x50_y3_CuN...
# 5   {'CA0': {'pstat_files': {'Sample12564_x42_y43_...
# 6   {'CA0': {'pstat_files': {'Sample12572_x46_y43_...
# 7   {'CA0': {'pstat_files': {'Sample9612_x46_y35_C...
# 8   {'CA0': {'pstat_files': {'Sample9604_x42_y35_C...
# 9   {'CA0': {'pstat_files': {'Sample15532_x46_y51_...
# 10  {'CA0': {'pstat_files': {'Sample15540_x50_y51_...
# 11  {'CA0': {'pstat_files': {'Sample15532_x46_y51_...
# 12  {'CA0': {'pstat_files': {'Sample12572_x46_y43_...
# 13  {'CA0': {'pstat_files': {'Sample9604_x42_y35_C...
# 14  {'CA0': {'pstat_files': {'Sample15509_x34_y51_...
# 15  {'CA2': {'pstat_files': {'Sample15516_x38_y51_...
# 16  {'CA4': {'pstat_files': {'Sample15516_x38_y51_...
# 17  {'CA4': {'pstat_files': {'Sample15516_x38_y51_...
# 18  {'CA3': {'pstat_files': {'Sample15509_x34_y51_...
#
#                              techs  \
# 0   [CA4, CA2, CA3, CA0, CA1, CV5]
# 1   [CA4, CA2, CA3, CA0, CA1, CV5]
# 2   [CA4, CA2, CA3, CA0, CA1, CV5]
# 3   [CA4, CA2, CA3, CA0, CA1, CV5]
# 4   [CA4, CA2, CA3, CA0, CA1, CV5]
# 5                  [CA0, CV6, CV5]
# 6                  [CA0, CV6, CV5]
# 7                       [CA0, CV5]
# 8                       [CA0, CV5]
# 9                       [CA0, CV5]
# 10                      [CA0, CV5]
# 11                      [CA0, CV5]
# 12                 [CA0, CV6, CV5]
# 13                      [CA0, CV5]
# 14                      [CA0, CA1]
# 15                      [CA2, CA0]
# 16                 [CA4, CA3, CA0]
# 17                      [CA4, CA0]
# 18                      [CA3, CA0]
#
#                                           tech_params  \
# 0   {'CA0': {'toggle_value': 0, 'acquisition_time'...
# 1   {'CA0': {'toggle_value': 0, 'acquisition_time'...
# 2   {'CA0': {'toggle_value': 0, 'acquisition_time'...
# 3   {'CA0': {'toggle_value': 0, 'acquisition_time'...
# 4   {'CA0': {'toggle_value': 0, 'acquisition_time'...
# 5   {'CA0': {'toggle_value': 0, 'acquisition_time'...
# 6   {'CA0': {'toggle_value': 0, 'acquisition_time'...
# 7   {'CV5': {'toggle_value': 2, 'potential_sweep_r...
# 8   {'CV5': {'toggle_value': 2, 'potential_sweep_r...
# 9   {'CV5': {'toggle_value': 2, 'potential_sweep_r...
# 10  {'CV5': {'toggle_value': 2, 'potential_sweep_r...
# 11  {'CV5': {'toggle_value': 2, 'potential_sweep_r...
# 12  {'CA0': {'toggle_value': 0, 'acquisition_time'...
# 13  {'CV5': {'toggle_value': 2, 'potential_sweep_r...
# 14  {'CA0': {'toggle_value': 0, 'acquisition_time'...
# 15  {'CA0': {'toggle_value': 0, 'acquisition_time'...
# 16  {'CA0': {'toggle_value': 0, 'acquisition_time'...
# 17  {'CA0': {'toggle_value': 0, 'acquisition_time'...
# 18  {'CA0': {'toggle_value': 0, 'acquisition_time'...
#
#                  tech_param_groups  \
# 0   [CA0, CA3, CA4, CA1, CA2, CV5]
# 1   [CA0, CA3, CA4, CA1, CA2, CV5]
# 2   [CA0, CA3, CA4, CA1, CA2, CV5]
# 3   [CA0, CA3, CA4, CA1, CA2, CV5]
# 4   [CA0, CA3, CA4, CA1, CA2, CV5]
# 5                  [CA0, CV6, CV5]
# 6                  [CA0, CV6, CV5]
# 7                       [CV5, CA0]
# 8                       [CV5, CA0]
# 9                       [CV5, CA0]
# 10                      [CV5, CA0]
# 11                      [CV5, CA0]
# 12                 [CA0, CV6, CV5]
# 13                      [CV5, CA0]
# 14                      [CA0, CA1]
# 15                      [CA0, CA2]
# 16                 [CA0, CA3, CA4]
# 17                      [CA0, CA4]
# 18                      [CA0, CA3]
#
#                                       tech_param_keys  \
# 0   [acquisition_time, toggle_dark_time_init, acqu...
# 1   [acquisition_time, toggle_dark_time_init, acqu...
# 2   [acquisition_time, toggle_dark_time_init, acqu...
# 3   [acquisition_time, toggle_dark_time_init, acqu...
# 4   [acquisition_time, toggle_dark_time_init, acqu...
# 5   [acquisition_time, toggle_dark_time_init, acqu...
# 6   [acquisition_time, toggle_dark_time_init, acqu...
# 7   [acquisition_time, toggle_dark_time_init, pote...
# 8   [acquisition_time, toggle_dark_time_init, pote...
# 9   [acquisition_time, toggle_dark_time_init, pote...
# 10  [acquisition_time, toggle_dark_time_init, pote...
# 11  [acquisition_time, toggle_dark_time_init, pote...
# 12  [acquisition_time, toggle_dark_time_init, acqu...
# 13  [acquisition_time, toggle_dark_time_init, pote...
# 14  [acquisition_time, toggle_dark_time_init, acqu...
# 15  [acquisition_time, toggle_dark_time_init, acqu...
# 16  [acquisition_time, toggle_dark_time_init, acqu...
# 17  [acquisition_time, toggle_dark_time_init, acqu...
# 18  [acquisition_time, toggle_dark_time_init, acqu...
#
#                                           root_params  \
# 0   {'file_format_version': 4, 'rcp_version': 2, '...
# 1   {'file_format_version': 4, 'rcp_version': 2, '...
# 2   {'file_format_version': 4, 'rcp_version': 2, '...
# 3   {'file_format_version': 4, 'rcp_version': 2, '...
# 4   {'file_format_version': 4, 'rcp_version': 2, '...
# 5   {'file_format_version': 4, 'rcp_version': 2, '...
# 6   {'file_format_version': 4, 'rcp_version': 2, '...
# 7   {'rcp_version': 2, 'file_format_version': 4, '...
# 8   {'rcp_version': 2, 'file_format_version': 4, '...
# 9   {'rcp_version': 2, 'file_format_version': 4, '...
# 10  {'rcp_version': 2, 'file_format_version': 4, '...
# 11  {'rcp_version': 2, 'file_format_version': 4, '...
# 12  {'file_format_version': 4, 'rcp_version': 2, '...
# 13  {'rcp_version': 2, 'file_format_version': 4, '...
# 14  {'rcp_version': 2, 'file_format_version': 4, '...
# 15  {'rcp_version': 2, 'file_format_version': 4, '...
# 16  {'file_format_version': 4, 'rcp_version': 2, '...
# 17  {'rcp_version': 2, 'file_format_version': 4, '...
# 18  {'rcp_version': 2, 'file_format_version': 4, '...
#
#                                             root_keys
# 0   [file_format_version, rcp_version, solution_ph...
# 1   [file_format_version, rcp_version, solution_ph...
# 2   [file_format_version, rcp_version, solution_ph...
# 3   [file_format_version, rcp_version, solution_ph...
# 4   [file_format_version, rcp_version, solution_ph...
# 5   [file_format_version, rcp_version, solution_ph...
# 6   [file_format_version, rcp_version, solution_ph...
# 7   [rcp_version, file_format_version, solution_ph...
# 8   [rcp_version, file_format_version, solution_ph...
# 9   [rcp_version, file_format_version, solution_ph...
# 10  [rcp_version, file_format_version, solution_ph...
# 11  [rcp_version, file_format_version, solution_ph...
# 12  [file_format_version, rcp_version, solution_ph...
# 13  [rcp_version, file_format_version, solution_ph...
# 14  [rcp_version, file_format_version, solution_ph...
# 15  [rcp_version, file_format_version, solution_ph...
# 16  [file_format_version, rcp_version, solution_ph...
# 17  [rcp_version, file_format_version, solution_ph...
# 18  [rcp_version, file_format_version, solution_ph...

# %% [markdown]
# __2d.__ Transform experiment list into dataframe

# %%
expdf = pd.DataFrame([vars(x) for _, x in p.exp_dict["eche"].items()])
expdf
# Out:
#                                                 path                     date  \
# 0  J:\hte_jcap_app_proto\share\pub\pub-2019060608...  2017-08-02 12:04:18 PDT
# 1  J:\hte_jcap_app_proto\share\pub\pub-2019060608...  2017-10-26 11:05:48 PDT
# 2  J:\hte_jcap_app_proto\share\pub\pub-2019060608...  2017-10-26 17:12:34 PDT
# 3  J:\hte_jcap_app_proto\share\pub\pub-2019060608...  2017-11-01 15:56:14 PDT
#
#    type  plate_id            elements  anneal_temp anneal_type  run_count  \
# 0  eche      2783  [Bi, Ar, O, Cu, V]        550.0           O          5
# 1  eche      2783  [Bi, Ar, O, Cu, V]        550.0           O          5
# 2  eche      2783  [Bi, Ar, O, Cu, V]        550.0           O          4
# 3  eche      2783  [Bi, Ar, O, Cu, V]        550.0           O          4
#
#                                            run_paths  \
# 0  [/eche/hte-eche-04/20170724_BiCuVO_27830/20170...
# 1  [/eche/hte-eche-04/20171025_CuBiVO_27830/20171...
# 2  [/eche/hte-eche-04/20171026_CuBiVO_27830/20171...
# 3  [/eche/hte-eche-04/20171101_CuBiVO_27830/20171...
#
#                                                files  \
# 0  {'CA4': {'pstat_files': {'Sample120_x50_y3_CuN...
# 1  {'CV5': {'pstat_files': {'Sample15524_x42_y51_...
# 2  {'CV5': {'pstat_files': {'Sample9604_x42_y35_C...
# 3  {'CA3': {'pstat_files': {'Sample15509_x34_y51_...
#
#                             techs  \
# 0  [CA4, CA2, CA3, CA0, CA1, CV5]
# 1                      [CV5, CV6]
# 2                      [CV5, CV6]
# 3            [CA3, CA4, CA2, CA1]
#
#                                                 runs
# 0  [<meadiator.core.meadiator.Run object at 0x000...
# 1  [<meadiator.core.meadiator.Run object at 0x000...
# 2  [<meadiator.core.meadiator.Run object at 0x000...
# 3  [<meadiator.core.meadiator.Run object at 0x000...

# %% [markdown]
# __2e.__ List all analyses in plate object `p`

# %%
anadf = pd.DataFrame([vars(x) for _, x in p.ana_dict["eche"].items()])
anadf
# Out:
#                                                 path                     date  \
# 0  J:\hte_jcap_app_proto\share\pub\pub-2019060608...  2017-08-02 12:03:09 PDT
# 1  J:\hte_jcap_app_proto\share\pub\pub-2019060608...  2017-10-26 11:09:54 PDT
# 2  J:\hte_jcap_app_proto\share\pub\pub-2019060608...  2017-10-26 17:12:37 PDT
# 3  J:\hte_jcap_app_proto\share\pub\pub-2019060608...  2017-11-01 15:54:31 PDT
# 4  J:\hte_jcap_app_proto\share\pub\pub-2019060608...  2018-04-09 16:12:43 PDT
# 5  J:\hte_jcap_app_proto\share\pub\pub-2019060608...  2018-07-16 14:33:17 PDT
#
#    type  plate_id            elements  anneal_temp anneal_type  \
# 0  eche      2783  [Bi, Ar, O, Cu, V]        550.0           O
# 1  eche      2783  [Bi, Ar, O, Cu, V]        550.0           O
# 2  eche      2783  [Bi, Ar, O, Cu, V]        550.0           O
# 3  eche      2783  [Bi, Ar, O, Cu, V]        550.0           O
# 4  eche      2783  [Bi, Ar, O, Cu, V]        550.0           O
# 5  eche      2783  [Bi, Ar, O, Cu, V]        550.0           O
#
#                                      experiment_path  \
# 0  /eche/20170802.120418.copied-20170802221206976...
# 1  /eche/20171026.110548.copied-20171026220643581...
# 2  /eche/20171026.171234.copied-20171026220643581...
# 3  /eche/20171101.155614.copied-20171101220429135...
# 4  /eche/20170802.120418.copied-20170802221206976...
# 5  /eche/20170802.120418.copied-20170802221206976...
#
#                                             analyses  \
# 0  {'ana__14': {'name': 'Analysis__Process_B_vs_A...
# 1  {'ana__1': {'name': 'Analysis__Iphoto', 'descr...
# 2  {'ana__1': {'name': 'Analysis__Iphoto', 'descr...
# 3  {'ana__1': {'name': 'Analysis__Iphoto', 'descr...
# 4  {'ana__14': {'name': 'Analysis__Process_B_vs_A...
# 5  {'ana__23': {'name': 'Analysis__FOM_Interp_Mer...
#
#                                       analysis_names  \
# 0  [Analysis__Process_B_vs_A_ByRun, Analysis__Pph...
# 1               [Analysis__Iphoto, Analysis__Iphoto]
# 2               [Analysis__Iphoto, Analysis__Iphoto]
# 3  [Analysis__Iphoto, Analysis__Iphoto, Analysis_...
# 4  [Analysis__Process_B_vs_A_ByRun, Analysis__Pph...
# 5  [Analysis__FOM_Interp_Merge_Ana, Analysis__FOM...
#
#                                                files  ana_count  \
# 0  {'CV5': {'image_files': {'ana__14-plate_id__27...         18
# 1  {'CV5': {'inter_files': {'ana__1__Sample9612_x...          2
# 2  {'CV5': {'inter_files': {'ana__1__Sample15516_...          2
# 3  {'CA1': {'image_files': {'ana__1-xy__ts-IA_sho...          4
# 4  {'CV5': {'image_files': {'ana__14-plate_id__27...         19
# 5  {'CV5': {'fom_files': {'ana__23__Pmax.W-Vpmax....         23
#
#                             techs  \
# 0       [CV5, CA4, CA1, CA2, CA3]
# 1                      [CV5, CV6]
# 2                      [CV5, CV6]
# 3            [CA1, CA2, CA3, CA4]
# 4  [CV5, CA4, CA1, CA0, CA2, CA3]
# 5       [CV5, CA4, CA3, CA2, CA1]
#
#                                           experiment
# 0  <meadiator.core.meadiator.Experiment object at...
# 1  <meadiator.core.meadiator.Experiment object at...
# 2  <meadiator.core.meadiator.Experiment object at...
# 3  <meadiator.core.meadiator.Experiment object at...
# 4  <meadiator.core.meadiator.Experiment object at...
# 5  <meadiator.core.meadiator.Experiment object at...

# %% [markdown]
# __2f.__ Show only analyses with `Analysis__Pphotomax` calculation

# %%
pmaxdf = anadf[anadf.apply(lambda x: "Analysis__Pphotomax" in x.analysis_names, axis=1)]
pmaxdf
# Out:
#                                                 path                     date  \
# 0  J:\hte_jcap_app_proto\share\pub\pub-2019060608...  2017-08-02 12:03:09 PDT
# 4  J:\hte_jcap_app_proto\share\pub\pub-2019060608...  2018-04-09 16:12:43 PDT
# 5  J:\hte_jcap_app_proto\share\pub\pub-2019060608...  2018-07-16 14:33:17 PDT
#
#    type  plate_id            elements  anneal_temp anneal_type  \
# 0  eche      2783  [Bi, Ar, O, Cu, V]        550.0           O
# 4  eche      2783  [Bi, Ar, O, Cu, V]        550.0           O
# 5  eche      2783  [Bi, Ar, O, Cu, V]        550.0           O
#
#                                      experiment_path  \
# 0  /eche/20170802.120418.copied-20170802221206976...
# 4  /eche/20170802.120418.copied-20170802221206976...
# 5  /eche/20170802.120418.copied-20170802221206976...
#
#                                             analyses  \
# 0  {'ana__14': {'name': 'Analysis__Process_B_vs_A...
# 4  {'ana__14': {'name': 'Analysis__Process_B_vs_A...
# 5  {'ana__23': {'name': 'Analysis__FOM_Interp_Mer...
#
#                                       analysis_names  \
# 0  [Analysis__Process_B_vs_A_ByRun, Analysis__Pph...
# 4  [Analysis__Process_B_vs_A_ByRun, Analysis__Pph...
# 5  [Analysis__FOM_Interp_Merge_Ana, Analysis__FOM...
#
#                                                files  ana_count  \
# 0  {'CV5': {'image_files': {'ana__14-plate_id__27...         18
# 4  {'CV5': {'image_files': {'ana__14-plate_id__27...         19
# 5  {'CV5': {'fom_files': {'ana__23__Pmax.W-Vpmax....         23
#
#                             techs  \
# 0       [CV5, CA4, CA1, CA2, CA3]
# 4  [CV5, CA4, CA1, CA0, CA2, CA3]
# 5       [CV5, CA4, CA3, CA2, CA1]
#
#                                           experiment
# 0  <meadiator.core.meadiator.Experiment object at...
# 4  <meadiator.core.meadiator.Experiment object at...
# 5  <meadiator.core.meadiator.Experiment object at...

# %%
i = 0  # look at first run in pmaxdf
anazip = os.path.basename(pmaxdf.path[i])
anatype = pmaxdf.type[i]

# %% [markdown]
# ***

# %% [markdown]
# __3a.__ Listing raw data in run object `r`

# %%
i = 0  # look at first run in rundf
runzip = os.path.basename(rundf.path[i])
runtype = rundf.type[i]
r = p.run_dict[runtype][runzip]
runfiles = r.list_data()

pprint(runfiles)
# Out:
# ['Sample27984_x42_y91_CuNaNBiNaNVNaNArNaN_CA4.txt',
#  'Sample28000_x50_y91_CuNaNBiNaNVNaNArNaN_CA2.txt',
#  'Sample28008_x54_y91_CuNaNBiNaNVNaNArNaN_CA3.txt',
#  'Sample27984_x42_y91_CuNaNBiNaNVNaNArNaN_CA0.txt',
#  'Sample28000_x50_y91_CuNaNBiNaNVNaNArNaN_CA1.txt',
#  'Sample27992_x46_y91_CuNaNBiNaNVNaNArNaN_CV5.txt']

# %% [markdown]
# __3b.__ Read raw data into numpy array

# %%
run_array = r.read_nparray("Sample27984_x42_y91_CuNaNBiNaNVNaNArNaN_CA4.txt")
run_array.shape
# Out:
# (80, 5)

# %% [markdown]
# __3c.__ Read raw data into pandas dataframe

# %%
r.read_dataframe("Sample27984_x42_y91_CuNaNBiNaNVNaNArNaN_CA4.txt")
# Out:
#     %column_headings=t(s)    Ewe(V)    Ach(V)      I(A)  Toggle
# 0                    0.05  0.485293 -0.001046  0.000085     0.0
# 1                    0.10  0.485193  0.001554  0.000085     0.0
# 2                    0.15  0.485193 -0.001246  0.000085     0.0
# 3                    0.20  0.485193  0.000654  0.000085     0.0
# 4                    0.25  0.485293  0.000654  0.000085     0.0
# ..                    ...       ...       ...       ...     ...
# 75                   3.80  0.485293 -0.000446  0.000085     4.0
# 76                   3.85  0.485293  0.001354  0.000085     4.0
# 77                   3.90  0.485293 -0.000946  0.000085     4.0
# 78                   3.95  0.485293 -0.000846  0.000085     4.0
# 79                   4.00  0.485193 -0.000246  0.000085     0.0
#
# [80 rows x 5 columns]

# %% [markdown]
# __3d.__ Listing raw data from experiment object `e`

# %%
i = 0  # look at first run in expdf
expzip = os.path.basename(expdf.path[i])
exptype = expdf.type[i]
e = p.exp_dict[exptype][expzip]
expfiles = e.list_data()

pprint(expfiles)
# Out:
# ['Sample120_x50_y3_CuNaNBiNaNVNaNArNaN_CA4.txt',
#  'Sample23932_x58_y75_CuNaNBiNaNVNaNArNaN_CA4.txt',
#  'Sample26224_x38_y83_CuNaNBiNaNVNaNArNaN_CA4.txt',
#  'Sample28016_x58_y91_CuNaNBiNaNVNaNArNaN_CA4.txt',
#  'Sample27984_x42_y91_CuNaNBiNaNVNaNArNaN_CA4.txt',
#  'Sample18437_x18_y59_CuNaNBiNaNVNaNArNaN_CA2.txt',
#  'Sample23932_x58_y75_CuNaNBiNaNVNaNArNaN_CA2.txt',
#  'Sample26264_x58_y83_CuNaNBiNaNVNaNArNaN_CA2.txt',
#  'Sample28016_x58_y91_CuNaNBiNaNVNaNArNaN_CA2.txt',
#  'Sample28000_x50_y91_CuNaNBiNaNVNaNArNaN_CA2.txt',
#  'Sample1911_x70_y11_CuNaNBiNaNVNaNArNaN_CA3.txt',
#  'Sample23932_x58_y75_CuNaNBiNaNVNaNArNaN_CA3.txt',
#  'Sample23885_x34_y75_CuNaNBiNaNVNaNArNaN_CA3.txt',
#  'Sample28024_x62_y91_CuNaNBiNaNVNaNArNaN_CA3.txt',
#  'Sample28008_x54_y91_CuNaNBiNaNVNaNArNaN_CA3.txt',
#  'Sample9573_x26_y35_CuNaNBiNaNVNaNArNaN_CA0.txt',
#  'Sample23924_x54_y75_CuNaNBiNaNVNaNArNaN_CA0.txt',
#  'Sample26232_x42_y83_CuNaNBiNaNVNaNArNaN_CA0.txt',
#  'Sample28024_x62_y91_CuNaNBiNaNVNaNArNaN_CA0.txt',
#  'Sample27984_x42_y91_CuNaNBiNaNVNaNArNaN_CA0.txt',
#  'Sample4251_x74_y19_CuNaNBiNaNVNaNArNaN_CA1.txt',
#  'Sample23940_x62_y75_CuNaNBiNaNVNaNArNaN_CA1.txt',
#  'Sample26295_x74_y83_CuNaNBiNaNVNaNArNaN_CA1.txt',
#  'Sample28016_x58_y91_CuNaNBiNaNVNaNArNaN_CA1.txt',
#  'Sample28000_x50_y91_CuNaNBiNaNVNaNArNaN_CA1.txt',
#  'Sample9683_x82_y35_CuNaNBiNaNVNaNArNaN_CV5.txt',
#  'Sample23940_x62_y75_CuNaNBiNaNVNaNArNaN_CV5.txt',
#  'Sample23869_x26_y75_CuNaNBiNaNVNaNArNaN_CV5.txt',
#  'Sample28016_x58_y91_CuNaNBiNaNVNaNArNaN_CV5.txt',
#  'Sample27992_x46_y91_CuNaNBiNaNVNaNArNaN_CV5.txt']

# %% [markdown]
# __3e.__ Read raw data into pandas dataframe. Note column names were present in the experiment attributes.

# %%
e.read_dataframe("Sample120_x50_y3_CuNaNBiNaNVNaNArNaN_CA4.txt")
# Out:
#     t(s)    Ewe(V)    Ach(V)      I(A)  Toggle
# 0   0.05  0.485293 -0.001046  0.000003     0.0
# 1   0.10  0.485293  0.001554  0.000003     0.0
# 2   0.15  0.485393  0.000754  0.000003     0.0
# 3   0.20  0.485293  0.000054  0.000003     0.0
# 4   0.25  0.485293 -0.000646  0.000003     0.0
# ..   ...       ...       ...       ...     ...
# 60  3.05  0.485293 -0.000246  0.000003     0.0
# 61  3.10  0.485293 -0.000346  0.000003     0.0
# 62  3.15  0.485293  0.002154  0.000003     0.0
# 63  3.20  0.485293  0.001154  0.000003     0.0
# 64  3.25  0.485293 -0.000446  0.000003     0.0
#
# [65 rows x 5 columns]

# %% [markdown]
# __3f.__ Listing data from analysis object `a`

# %%
i = 0  # look at first run in expdf
anazip = os.path.basename(pmaxdf.path[i])
anatype = pmaxdf.type[i]
a = p.ana_dict[anatype][anazip]
anafiles = a.list_data()
anafiles.sort(key=lambda x: int(x.replace("-", "__").split("__")[1]))

pprint(anafiles[:5])
# Out:
# ['ana__1__I.A_photo-I.A_photo_ill-I.A_photo_dark.csv',
#  'ana__1__Sample26224_x38_y83_CuNaNBiNaNVNaNArNaN_CA1_interlen.txt',
#  'ana__1__Sample28024_x62_y91_CuNaNBiNaNVNaNArNaN_CA1_interlen.txt',
#  'ana__1__Sample27984_x42_y91_CuNaNBiNaNVNaNArNaN_CA1_interlen.txt',
#  'ana__1__Sample23940_x62_y75_CuNaNBiNaNVNaNArNaN_CA1_interlen.txt']

# %%
# figure of merit csvs
pprint([fomcsv for fomcsv in anafiles if fomcsv.endswith(".csv")][-5:])
# Out:
# ['ana__14__Voc.V-Vpmax.V-Fill_factor.csv',
#  'ana__15__Pmax.W-Vpmax.V-Ipmax.A.csv',
#  'ana__16__Voc.V-Vpmax.V-Fill_factor.csv',
#  'ana__17__Pmax.W-Vpmax.V-Ipmax.A.csv',
#  'ana__18__Voc.V-Vpmax.V-Fill_factor.csv']

# %% [markdown]
# __3g.__ Reading figure of merit data from analysis object `a`

# %%
a.read_dataframe('ana__15__Pmax.W-Vpmax.V-Ipmax.A.csv')
# Out:
#      sample_no  runint  plate_id        Pmax.W  Vpmax.V       Ipmax.A  Voc.V  \
# 0      15564.0     1.0    2783.0  4.168480e-07    0.197  2.115980e-06  0.368
# 1       6877.0     1.0    2783.0  9.711780e-06    0.384  2.529110e-05  0.399
# 2      15469.0     1.0    2783.0  1.876220e-10    0.061  3.075760e-09    NaN
# 3       1888.0     1.0    2783.0  3.501500e-06    0.249  1.406230e-05  0.399
# 4      18524.0     1.0    2783.0  3.013410e-07    0.206  1.462820e-06  0.327
# ..         ...     ...       ...           ...      ...           ...    ...
# 185    23908.0     3.0    2783.0  2.348710e-06   -0.300 -7.829040e-06  0.399
# 186    26279.0     3.0    2783.0  1.903450e-06   -0.300 -6.344820e-06  0.399
# 187    26272.0     3.0    2783.0  2.302540e-06   -0.300 -7.675130e-06  0.399
# 188    26224.0     3.0    2783.0  2.696680e-06   -0.300 -8.988930e-06  0.399
# 189    26240.0     3.0    2783.0  2.288430e-06   -0.300 -7.628090e-06  0.399
#
#             Isc.A  Fill_factor           RSS  sigFit_upper.A  \
# 0    2.698120e-06     0.419825  1.654520e-13    2.706580e-06
# 1    4.731220e-05     0.514461  3.388770e-12    1.123870e-04
# 2    5.478620e-09     0.114154  7.270460e-18    8.332170e-09
# 3    2.854740e-05     0.307408  1.684280e-12    6.947250e-03
# 4    1.680390e-06     0.548402  1.218790e-12    1.680500e-06
# ..            ...          ...           ...             ...
# 185 -7.826960e-06     0.752080  1.796890e-12   -7.829040e-06
# 186 -6.336580e-06     0.752858  4.062250e-14   -6.344820e-06
# 187 -7.669090e-06     0.752471  3.928230e-14   -7.675130e-06
# 188 -8.848740e-06     0.763792  5.747970e-14   -8.988930e-06
# 189 -7.596510e-06     0.755005  5.698570e-14   -7.628090e-06
#
#      sigFit_inflection.V  sigFit_shape.V  sigFit_upper_err.A  \
# 0               0.257392        0.044080        1.997600e-07
# 1               6.530560        1.307160        3.510860e-03
# 2               0.249668        0.091413        4.832550e-09
# 3             -13.810600        4.216930        4.450880e+01
# 4               0.258970        0.026707        4.049720e-07
# ..                   ...             ...                 ...
# 185             0.168187        0.020515        6.174470e-07
# 186             0.115435        0.017416        1.280460e-07
# 187             0.118686        0.016638        1.231490e-07
# 188             0.092060        0.022279        3.151250e-07
# 189             0.107924        0.019742        1.700750e-07
#
#      sigFit_inflection_err.V  sigFit_shape_err.V  sigFit_lower.A  \
# 0                   0.017973            0.016890   -2.083610e-07
# 1                8009.330000          119.010000   -9.571940e-03
# 2                   0.027167            0.034496   -3.832710e-08
# 3               32376.400000         1881.910000   -2.330850e-04
# 4                   0.045178            0.039827   -1.191300e-07
# ..                       ...                 ...             ...
# 185                 0.010972            0.009861   -2.577800e-07
# 186                 0.002221            0.001375   -1.017460e-07
# 187                 0.001857            0.001006   -1.060070e-07
# 188                 0.002460            0.002873   -1.131220e-07
# 189                 0.002063            0.001834   -1.241520e-07
#
#      sigFit_lower_err.A
# 0          3.571950e-07
# 1          5.508740e+01
# 2          8.287570e-09
# 3          5.759220e-02
# 4          5.856380e-07
# ..                  ...
# 185        4.646250e-07
# 186        5.929760e-08
# 187        5.814690e-08
# 188        7.213570e-08
# 189        7.094430e-08
#
# [190 rows x 18 columns]

# %% [markdown]
# __3h.__ Summarizing analysis blocks

# %%
ana_blockdf = pd.DataFrame(vars(a)["analyses"]).T.reset_index()
# sort by ana__#
ana_blockdf = ana_blockdf.assign(ana_idx = lambda df: df['index'].map(lambda x: int(x.split("__")[-1])))
ana_blockdf.sort_values("ana_idx", inplace=True)
ana_blockdf.reset_index(drop=True, inplace=True)

ana_blockdf
# Out:
#       index                            name  \
# 0    ana__1                Analysis__Iphoto
# 1    ana__2  Analysis__Process_B_vs_A_ByRun
# 2    ana__3                Analysis__Iphoto
# 3    ana__4  Analysis__Process_B_vs_A_ByRun
# 4    ana__5                Analysis__Iphoto
# 5    ana__6  Analysis__Process_B_vs_A_ByRun
# 6    ana__7                Analysis__Iphoto
# 7    ana__8  Analysis__Process_B_vs_A_ByRun
# 8    ana__9         Analysis__SpectralPhoto
# 9   ana__10                Analysis__Iphoto
# 10  ana__11             Analysis__Pphotomax
# 11  ana__12  Analysis__Process_B_vs_A_ByRun
# 12  ana__13             Analysis__Pphotomax
# 13  ana__14  Analysis__Process_B_vs_A_ByRun
# 14  ana__15             Analysis__Pphotomax
# 15  ana__16  Analysis__Process_B_vs_A_ByRun
# 16  ana__17             Analysis__Pphotomax
# 17  ana__18  Analysis__Process_B_vs_A_ByRun
#
#                                           description version  \
# 0   I.A_photo,I.A_photo_ill,I.A_photo_dark on CA1;...       1
# 1   process B relative to A in ana__1; run 1,2,3,4...     1.2
# 2   I.A_photo,I.A_photo_ill,I.A_photo_dark on CA2;...       1
# 3   process B relative to A in ana__3; run 1,2,3,4...     1.2
# 4   I.A_photo,I.A_photo_ill,I.A_photo_dark on CA3;...       1
# 5   process B relative to A in ana__5; run 1,2,3,4...     1.2
# 6   I.A_photo,I.A_photo_ill,I.A_photo_dark on CA4;...       1
# 7   process B relative to A in ana__7; run 1,2,3,4...     1.2
# 8   num_wavelengths on CA1; run 1,2,3,4,5; plate_i...       2
# 9   I.A_photo,I.A_photo_ill,I.A_photo_dark on CV5;...       1
# 10  Pmax.W,Vpmax.V,Ipmax.A,Voc.V,Isc.A,Fill_factor...       4
# 11  process B relative to A in ana__11; run 1,2,3,...     1.2
# 12  Pmax.W,Vpmax.V,Ipmax.A,Voc.V,Isc.A,Fill_factor...       4
# 13  process B relative to A in ana__13; run 1,2,3,...     1.2
# 14  Pmax.W,Vpmax.V,Ipmax.A,Voc.V,Isc.A,Fill_factor...       4
# 15  process B relative to A in ana__15; run 1,2,3,...     1.2
# 16  Pmax.W,Vpmax.V,Ipmax.A,Voc.V,Isc.A,Fill_factor...       4
# 17  process B relative to A in ana__17; run 1,2,3,...     1.2
#
#                                            parameters technique  ana_idx
# 0   {'from_end': 'true', 'num_illum_cycles': 2, 'i...       CA1        1
# 1   {'select_ana': 'ana__1', 'fom_keys_B': 'I.A_ph...       CA1        2
# 2   {'from_end': 'true', 'num_illum_cycles': 2, 'i...       CA2        3
# 3   {'select_ana': 'ana__3', 'fom_keys_B': 'I.A_ph...       CA2        4
# 4   {'from_end': 'true', 'num_illum_cycles': 2, 'i...       CA3        5
# 5   {'select_ana': 'ana__5', 'fom_keys_B': 'I.A_ph...       CA3        6
# 6   {'from_end': 'true', 'num_illum_cycles': 2, 'i...       CA4        7
# 7   {'select_ana': 'ana__7', 'fom_keys_B': 'I.A_ph...       CA4        8
# 8   {'optical_power_mw': 'illumination_intensity',...       CA1        9
# 9   {'from_end': 'true', 'num_illum_cycles': 2, 'i...       CV5       10
# 10  {'weight': 'false', 'use_sweeps_from_end': 'tr...       CV5       11
# 11  {'select_ana': 'ana__11', 'fom_keys_B': 'Pmax....       CV5       12
# 12  {'weight': 'false', 'use_sweeps_from_end': 'tr...       CV5       13
# 13  {'select_ana': 'ana__13', 'fom_keys_B': 'Pmax....       CV5       14
# 14  {'weight': 'false', 'use_sweeps_from_end': 'tr...       CV5       15
# 15  {'select_ana': 'ana__15', 'fom_keys_B': 'Pmax....       CV5       16
# 16  {'weight': 'false', 'use_sweeps_from_end': 'tr...       CV5       17
# 17  {'select_ana': 'ana__17', 'fom_keys_B': 'Pmax....       CV5       18
